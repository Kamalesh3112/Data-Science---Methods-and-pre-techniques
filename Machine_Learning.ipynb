# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Salaries.csv') #DataSource

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.shape
# Out:
# (78, 6)

# %%
df.size
# Out:
# 468

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.tail(30).mean()
# Out:
# phd           16.500000
# service       10.966667
# salary     99029.000000
# dtype: float64

# %%
df =  pd.DataFrame({ 'Name': pd.Series(['Alice','Bob','Chris']), 

                  'Age': pd.Series([ 21,25,23]) } )

print(df)

#Add a new column:

df['height'] = pd.Series([5.2,6.0,5.6])

print(df)
# Out:
#     Name  Age
# 0  Alice   21
# 1    Bob   25
# 2  Chris   23
#     Name  Age  height
# 0  Alice   21     5.2
# 1    Bob   25     6.0
# 2  Chris   23     5.6

# %%
import pandas as pd
df = pd.read_csv('/Salaries.csv')

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df[['rank','salary']].plot()

# %%
df['salary'] = pd.Series('Sex')
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb04f321494a> in <module>()
# ----> 1 df['salary'] = pd.Series('Sex')
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
df['salary'].describe()
# Out:
# count       1
# unique      1
# top       Sex
# freq        1
# Name: salary, dtype: object

# %%
df['service'].describe()
# Out:
# count    78.000000
# mean     15.051282
# std      12.139768
# min       0.000000
# 25%       5.250000
# 50%      14.500000
# 75%      20.750000
# max      51.000000
# Name: service, dtype: float64

# %%
df_rank = df.groupby('rank')
df_rank.mean()
# Out:
#                  phd    service
# rank
# AssocProf  15.076923  11.307692
# AsstProf    5.052632   2.210526
# Prof       27.065217  21.413043

# %%
g = df.groupby('sex')
g.mean()
# Out:
#               phd    service
# sex
# Female  16.512821  11.564103
# Male    22.897436  18.538462

# %%
df_rank = df.groupby('rank')
df_rank.mean()
# Out:
#                  phd    service
# rank
# AssocProf  15.076923  11.307692
# AsstProf    5.052632   2.210526
# Prof       27.065217  21.413043

# %%
g = df.groupby('sex')
g.mean()
# Out:
#               phd    service
# sex
# Female  16.512821  11.564103
# Male    22.897436  18.538462

# %%
g = df.groupby('salary')
g.mean()
# Out:
#         phd  service
# salary
# Sex      56       49

# %%
df_rank = df.groupby('rank')
df_rank.mean()
# Out:
#                  phd    service
# rank
# AssocProf  15.076923  11.307692
# AsstProf    5.052632   2.210526
# Prof       27.065217  21.413043

# %%
import pandas as pd
df = pd.read_csv('/Salaries.csv')

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df_rank = df.groupby('rank')
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df['salary']>160000
df_sub = df[df['salary']>160000]
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101

# %%
df_sub = df[df['salary']>100000]
df_sub
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 7        Prof          A   18       18    Male  126300
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# ...

# %%
df[df['discipline']=='A']['salary'].mean()
# Out:
# 98331.11111111111

# %%
df[df['discipline']=='B']['salary'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bcd8b9111eab> in <module>()
# ----> 1 df[df['discipline']=='B']['salary'].mean()
#
# NameError: name 'df' is not defined

# %%
df[df['salary']>100000].groupby('sex')[['salary']].count()
# Out:
#         salary
# sex
# Female      21
# Male        25

# %%
df[0:1]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960

# %%
df[0:9:2]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 2       Prof          A   23       20  Male  110515
# 4       Prof          B   20       18  Male  104800
# 6  AssocProf          A   20       17  Male   81285
# 8       Prof          A   29       19  Male   94350

# %%
df[0:20:6]
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 6   AssocProf          A   20       17  Male   81285
# 12   AsstProf          B    1        0  Male   88000
# 18       Prof          A   19        7  Male  107300

# %%
df[0:78:2]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 10       Prof          B   39       33    Male  128250
# 12   AsstProf          B    1        0    Male   88000
# 14       Prof          B   25       19    Male  153750
# 16   AsstProf          B    8        3    Male   75044
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 24       Prof          A   30       23    Male   91100
# 26       Prof          A   38       19    Male  148750
# 28   AsstProf          B    7        2    Male   91300
# 30  AssocProf          B    9        7    Male  107008
# ...

# %%
df[df['salary']>120000].groupby('sex')[['salary']].count()
# Out:
#         salary
# sex
# Female       9
# Male        16

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df[10:30]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500
# 20  AsstProf          B    4        4  Male   92000
# 21      Prof          A   33       30  Male  103106
# 22  AsstProf          A    4        2  Male   73000
# 23  AsstProf          A    2        0  Male   85000
# 24      Prof          A   30       23  Male   91100
# 25      Prof          B   35       31  Male   99418
# 26      Prof          A   38       19  Male  148750
# ...

# %%
df.iloc[:,1]
# Out:
# 0     B
# 1     A
# 2     A
# 3     A
# 4     B
#      ..
# 73    B
# 74    B
# 75    B
# 76    A
# 77    A
# Name: discipline, Length: 78, dtype: object

# %%
df.iloc(0)

# %%
df.iloc[:,1:3]
# Out:
#    discipline  phd
# 0           B   56
# 1           A   12
# 2           A   23
# 3           A   40
# 4           B   20
# ..        ...  ...
# 73          B   18
# 74          B   19
# 75          B   17
# 76          A   28
# 77          A   23
#
# [78 rows x 2 columns]

# %%
df.iloc[1:3,0:2]
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[0:3,1:4]
# Out:
#   discipline  phd  service
# 0          B   56       49
# 1          A   12        6
# 2          A   23       20

# %%
df.loc[10:20,['rank','salary']]
# Out:
#         rank  salary
# 10      Prof  128250
# 11      Prof  134778
# 12  AsstProf   88000
# 13      Prof  162200
# 14      Prof  153750
# 15      Prof  150480
# 16  AsstProf   75044
# 17  AsstProf   92000
# 18      Prof  107300
# 19      Prof  150500
# 20  AsstProf   92000

# %%
#sorting

# %%
df_sorted = df.sort_values(by = 'service')
df_sorted.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000

# %%
df.loc[10:40,['rank','salary']]
# Out:
#          rank  salary
# 10       Prof  128250
# 11       Prof  134778
# 12   AsstProf   88000
# 13       Prof  162200
# 14       Prof  153750
# 15       Prof  150480
# 16   AsstProf   75044
# 17   AsstProf   92000
# 18       Prof  107300
# 19       Prof  150500
# 20   AsstProf   92000
# 21       Prof  103106
# 22   AsstProf   73000
# 23   AsstProf   85000
# 24       Prof   91100
# 25       Prof   99418
# 26       Prof  148750
# 27       Prof  155865
# 28   AsstProf   91300
# 29       Prof  123683
# 30  AssocProf  107008
# 31       Prof  155750
# 32       Prof  103275
# 33       Prof  120000
# 34  AssocProf  119800
# 35       Prof  126933
# 36       Prof  146856
# 37       Prof  102000
# 38   AsstProf   91000
# 39       Prof  129000
# 40       Prof  137000

# %%
df_sorted = df.sort_values(by = 'salary')
df_sorted.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 57   AsstProf          A    3        1  Female   72500

# %%
df.sort_values(by =['service','salary'],ascending =['True','False'])
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 43  AsstProf          B    5        0  Female   77000
# 23  AsstProf          A    2        0    Male   85000
# 12  AsstProf          B    1        0    Male   88000
# 17  AsstProf          B    4        0    Male   92000
# ..       ...        ...  ...      ...     ...     ...
# 40      Prof          A   39       36  Female  137000
# 27      Prof          A   45       43    Male  155865
# 36      Prof          B   45       45    Male  146856
# 0       Prof          B   56       49    Male  186960
# 9       Prof          A   51       51    Male   57800
#
# [78 rows x 6 columns]

# %%
df.sort_values(by =['service','salary'],ascending =['True','False'])
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 43  AsstProf          B    5        0  Female   77000
# 23  AsstProf          A    2        0    Male   85000
# 12  AsstProf          B    1        0    Male   88000
# 17  AsstProf          B    4        0    Male   92000
# ..       ...        ...  ...      ...     ...     ...
# 40      Prof          A   39       36  Female  137000
# 27      Prof          A   45       43    Male  155865
# 36      Prof          B   45       45    Male  146856
# 0       Prof          B   56       49    Male  186960
# 9       Prof          A   51       51    Male   57800
#
# [78 rows x 6 columns]

# %%
#Aggregation Function(agg)
df.max()
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df[['service','salary']].agg(['min','mean','max'])
# Out:
#         service         salary
# min    0.000000   57800.000000
# mean  15.051282  108023.782051
# max   51.000000  186960.000000

# %%
df.agg({'salary':['min','mean','max'],'service':['nunique']})
# Out:
#                 salary  service
# max      186960.000000      NaN
# mean     108023.782051      NaN
# min       57800.000000      NaN
# nunique            NaN     33.0

# %%
#Matplotlib Library

# %%
from matplotlib  import pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])
plt.show()

# %%
plt.plot([10,20,30],[40,70,90])
plt.show()

# %%
plt.plot([55,45,65],[75,85,35])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([11,22,33],[44,55,66])
plt.title('Sample Visualization')
plt.xlabel('Sample X')
plt.ylabel('Sample Y')
plt.show()

# %%
x = [12,23,45]
y = [26,57,68]
plt.plot(x,y,'r',c='red')
plt.show()

# %%
x = [14,56,98]
y = [58,96,78]
x2 = [56,85,24]
y2 = [53,87,69]
plt.plot(x,y,'c',label='Sample 1',linewidth=5)
plt.plot(x2,y2,'r',label='Sample 2',linewidth=5)
plt.title('Element Visualization')
plt.xlabel('Element 1')
plt.ylabel('Element 2')
plt.legend()
plt.show()

# %%
#Bar Graph

# %%
plt.bar([10,20,30],[40,50,60])
plt.title('Bar Sample Visualization')
plt.xlabel('Bar Element A')
plt.ylabel('Bar Element B')
plt.show()

# %%
plt.bar([0.75,1.75,2.75,3.75,4.75],[50,40,70,80,20],label='koenisegg',color='red', width=0.1)
plt.bar([0.25,1.25,2.25,3.25,4.25],[80,20,20,50,60],label='Bugatti',color='blue', width=0.5)
plt.legend()
plt.title('Bar Vusualization of Sample data')
plt.xlabel('Data a')
plt.ylabel('Data b')
plt.show()

# %%
#Histogram

# %%
age = [5,6,5,18,19,29,18,18,20,20,25,24,23,22,24,18]
numbers = [0,5,10,15,20,25,30,35]
plt.hist(age,numbers,histtype='step')
plt.show()

# %%
x = [4.5,5.5,6.5,7.5,8.5]
y = [10,20,30,40,50]

x1 = [2.4,3.4,4.4,5.4,6.4]
y1 = [20,40,60,80,90]
plt.scatter(x,y,color = 'orange',label = 'Scatter one')
plt.scatter(x1,y1,color = 'blue',label = 'Scatter second')
plt.title('Scatter visualization')
plt.xlabel('Data First')
plt.ylabel('Data Second')
plt.legend()
plt.show()

# %%
import numpy as np

plt.plot([12,36,45,58,69],[23,34,48,57,68],'ro-',label='elbow1')
plt.plot([12,36,45,58,69],[24,35,49,58,70],'ro-',label='elbow2')
plt.plot([12,36,45,58,69],[26,36,51,59,71],'go',label='Dot')
plt.title('Elbow Shaped Visualization')
plt.legend()
plt.plot()
# Out:
# []

# %%
t = np.range(1.5,0.3)
plt.plot(t,t,'r--',t,t*2,'go')

# %%
t = np.arange(2,5,0.3)
plt.plot(t,t,'r--',t,t*5,'go')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mydata = pd.read_csv('/content/BTC_INR_Historical Data.csv')

# %%
mydata.head()
# Out:
#         Date         Open         High  ...        Close    Adj Close        Volume
# 0  9/18/2019  734975.8750  731490.6875  ...  725961.0000  725961.0000  1.151010e+12
# 1  9/19/2019  726121.0000  735039.7500  ...  732951.1875  732951.1875  1.423410e+12
# 2  9/20/2019  732944.3125  732415.8125  ...  724993.9375  724993.9375  1.049160e+12
# 3  9/21/2019  725136.8750  725453.6875  ...  713463.9375  713463.9375  9.559600e+11
# 4  9/22/2019  713777.1250  717307.0625  ...  717018.5625  717018.5625  9.398240e+11
#
# [5 rows x 7 columns]

# %%
mydata.head(10)
# Out:
#         Date         Open         High  ...        Close    Adj Close        Volume
# 0  9/18/2019  734975.8750  731490.6875  ...  725961.0000  725961.0000  1.151010e+12
# 1  9/19/2019  726121.0000  735039.7500  ...  732951.1875  732951.1875  1.423410e+12
# 2  9/20/2019  732944.3125  732415.8125  ...  724993.9375  724993.9375  1.049160e+12
# 3  9/21/2019  725136.8750  725453.6875  ...  713463.9375  713463.9375  9.559600e+11
# 4  9/22/2019  713777.1250  717307.0625  ...  717018.5625  717018.5625  9.398240e+11
# 5  9/23/2019  716845.5625  713261.0000  ...  688840.8750  688840.8750  1.072270e+12
# 6  9/24/2019  688840.6875  695793.7500  ...  611785.2500  611785.2500  1.774410e+12
# 7  9/25/2019  610569.0000  620775.8750  ...  602472.6875  602472.6875  1.543610e+12
# 8  9/26/2019  602520.7500  604371.3750  ...  576215.6875  576215.6875  1.366780e+12
# 9  9/27/2019  575799.3125  584457.3750  ...  583067.1250  583067.1250  1.159440e+12
#
# [10 rows x 7 columns]

# %%
mydata.tail()
# Out:
#           Date        Open        High  ...       Close   Adj Close        Volume
# 614  5/24/2021  2530005.25  2904816.25  ...  2819221.50  2819221.50  4.906260e+12
# 615  5/25/2021  2825762.25  2897192.25  ...  2795880.00  2795880.00  4.092520e+12
# 616  5/26/2021  2795181.00  2964039.25  ...  2855617.50  2855617.50  3.731510e+12
# 617  5/27/2021  2857266.50  2931485.50  ...  2793746.75  2793746.75  3.140740e+12
# 618  5/28/2021  2775090.50  2817991.75  ...  2671672.75  2671672.75  3.007150e+12
#
# [5 rows x 7 columns]

# %%
import numpy as np
from matplotlib import pyplot as plt
t = np.arange(4,5,0.4)
plt.plot(t,t,'r--',t,t*2,'ro-')

# %%
t = np.arange(5,10,0.8)
plt.plot(t,t,'r--',t,t*2,'go')

# %%
plt.plot([10,20,30],[40,50,60],'ro-',label ='Elbow 1')
plt.plot([10,20,30],[41,51,61],'ro-',label ='Elbow 2')
plt.plot([11,21,31],[44,56,69],'go',label ='Elbow3')
plt.title('Sample Elbow Graph')
plt.xlabel('Elbow A')
plt.ylabel('Elbow B')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.plot([1,2,3,4],[1,4,9,12],'ro-',label = 'Line 1')
plt.plot([1,2,3,4],[1,2,3,4],linewidth = 5,color='green',label = 'line 2')
plt.plot([5,6,7,8,9],[5,6,7,8,9],'ro-',label='line3')
plt.plot([5,6,7,8,9],[6,6,6,6,6],color = 'red',linestyle = '-',marker = 'o',markersize = '5',markerfacecolor = 'g')
#[xmin,xmax,ymin,ymax]
plt.plot([0,10,0,20])
plt.legend()
plt.show()
t = np.arange(0,5,0.2)
plt.plot(t,t,'r-',t,t**4,'c^')

# %%
x = [48,16,45]
y = [25,34,78]
x2 = [12,36,69]
y2 = [23,45,89]

plt.plot(x,y,label = 'line1',linewidth =6)
plt.plot(x2,y2, label = 'line2', linewidth = 7)
plt.title('Raising Visual')
plt.xlabel('Raising 1')
plt.ylabel('Raising 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5]
sleeping =[7,8,6,11,7]
eating = [2,3,4,3,2]
working =[7,8,7,2,2]
playing = [8,5,7,8,13]
plt.plot([],[],color='m', label='Sleeping', linewidth=5)
plt.plot([],[],color='c', label='Eating', linewidth=5)
#plt.plot([],[],color='r', label='Working', linewidth=5)
#plt.plot([],[],color='k', label='Playing', linewidth=5)
plt.stackplot(days, sleeping,eating,working,playing,
              colors=['m','c','r','k'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Stack Plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
days = [12,23,45,56,67]
sleeping = [23,34,45,56,67]
eating = [22,34,46,57,68]
working = [29,40,50,60,70]
playing = [31,42,53,64,75]
plt.plot([],[],color = 'm',label = 'sleeping',linewidth = 5)
plt.plot([],[],color = 'c',label = 'eating',linewidth = 5)
plt.plot([],[],color = 'r',label = 'working',linewidth = 5)
plt.plot([],[],color = 'k',label = 'playing',linewidth  = 5)
plt.stackplot(days,sleeping,eating,working,playing,colors=['m','c','r','k'])
plt.title('Stack plot Dimensions')
plt.xlabel('Plot A')
plt.ylabel('Plot B')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.plot([5,6,7,8],[1,2,3,4],'ro-',label = 'line 1')
plt.plot([5,6,7,8],[1,2,3,4],linewidth = 6,label = 'line 2')
plt.plot([5,6,7,8,9],[7,7,7,7,7],'ro-',label = 'line 3')
plt.plot([5,6,7,8,9],[2,3,4,8,10],linestyle = '-',color = 'red',marker = 'o',markersize = 5, markerfacecolor = 'g')
plt.plot(0,10,0,3)
plt.legend()
plt.show()
t = np.arange(3,5,0.4)
print(t,t,'r-',t,t**4,'c^')
# Out:
# [3.  3.4 3.8 4.2 4.6] [3.  3.4 3.8 4.2 4.6] r- [3.  3.4 3.8 4.2 4.6] [ 81.     133.6336 208.5136 311.1696 447.7456] c^

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5]
slices = [13,3,3,14]
activities = ['sleeping','eating' , 'working','playing']
color = ['c','m','r','k']
plt.pie(slices,labels = activities,colors = color,startangle=180)
plt.title('Pie chart Visualization')
plt.show()

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5]
slices = [20,20,40,20]
activities = ['playing','chatting','Eating','Learning']
color = ['c','m','r','k']
plt.pie(slices,labels = activities,colors=color,startangle=180)
plt.title('Pie Chart Visualization')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
  return np.exp(-t)*np.sin(2*np.pi*t)
t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.sin(2*np.pi*t2))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0,0.5,0.1)
t2 = np.arange(0.0,0.5,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'b',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0,0.5,0.1)
t2 = np.arange(0.0,0.5,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)
# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')
# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')
# Show the figure.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x =np.arange(0,3*np.pi,0.3)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.subplot(2,1,1)
plt.title('Sine')
plt.plot(x,y_sin)
plt.subplot(2,1,2)
plt.title('Cosine')
plt.plot(x,y_cos)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/salaryData.csv')

# %%
print(data)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
data.head(28)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.shape
# Out:
# (30, 2)

# %%
data.loc[1:20,['YearsExperience','Salary']]
# Out:
#     YearsExperience   Salary
# 1               1.3  46205.0
# 2               1.5  37731.0
# 3               2.0  43525.0
# 4               2.2  39891.0
# 5               2.9  56642.0
# 6               3.0  60150.0
# 7               3.2  54445.0
# 8               3.2  64445.0
# 9               3.7  57189.0
# 10              3.9  63218.0
# 11              4.0  55794.0
# 12              4.0  56957.0
# 13              4.1  57081.0
# 14              4.5  61111.0
# 15              4.9  67938.0
# 16              5.1  66029.0
# 17              5.3  83088.0
# 18              5.9  81363.0
# 19              6.0  93940.0
# 20              6.8  91738.0

# %%
data.Salary.value_counts()
# Out:
# 109431.0    1
# 37731.0     1
# 56957.0     1
# 57081.0     1
# 63218.0     1
# 91738.0     1
# 98273.0     1
# 46205.0     1
# 60150.0     1
# 105582.0    1
# 122391.0    1
# 64445.0     1
# 121872.0    1
# 112635.0    1
# 93940.0     1
# 39891.0     1
# 81363.0     1
# 57189.0     1
# 61111.0     1
# 56642.0     1
# 43525.0     1
# 101302.0    1
# 66029.0     1
# 55794.0     1
# 54445.0     1
# 39343.0     1
# 116969.0    1
# 67938.0     1
# 113812.0    1
# 83088.0     1
# Name: Salary, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.max()
# Out:
# YearsExperience        10.5
# Salary             122391.0
# dtype: float64

# %%
data.min()
# Out:
# YearsExperience        1.1
# Salary             37731.0
# dtype: float64

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.ndim
# Out:
# 2

# %%
data.iloc[2:6]
# Out:
#    YearsExperience   Salary
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0

# %%
data_Salary = data[data['Salary']>20000]
data_Salary.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data_Salary = data[data['Salary']>30000]
data_Salary.mean()
# Out:
# YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64

# %%
data[data['Salary']>16000].groupby('YearsExperience')[['Salary']].count()
# Out:
#                  Salary
# YearsExperience
# 1.1                   1
# 1.3                   1
# 1.5                   1
# 2.0                   1
# 2.2                   1
# 2.9                   1
# 3.0                   1
# 3.2                   2
# 3.7                   1
# 3.9                   1
# 4.0                   2
# 4.1                   1
# 4.5                   1
# 4.9                   1
# 5.1                   1
# 5.3                   1
# 5.9                   1
# 6.0                   1
# 6.8                   1
# 7.1                   1
# 7.9                   1
# 8.2                   1
# 8.7                   1
# 9.0                   1
# 9.5                   1
# 9.6                   1
# 10.3                  1
# 10.5                  1

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
data.nunique()
# Out:
# YearsExperience    28
# Salary             30
# dtype: int64

# %%
data.agg({'Salary':['min','mean','max'],'YearsExperience':['nunique']})
# Out:
#            Salary  YearsExperience
# max      122391.0              NaN
# mean      76003.0              NaN
# min       37731.0              NaN
# nunique       NaN             28.0

# %%
data_sorted =  data.sort_values('Salary')
data_sorted.head()
# Out:
#    YearsExperience   Salary
# 2              1.5  37731.0
# 0              1.1  39343.0
# 4              2.2  39891.0
# 3              2.0  43525.0
# 1              1.3  46205.0

# %%
data.sort_values(['YearsExperience','Salary'],ascending=['True','False'])
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
g = data.groupby('Salary')
g.mean()
# Out:
#           YearsExperience
# Salary
# 37731.0               1.5
# 39343.0               1.1
# 39891.0               2.2
# 43525.0               2.0
# 46205.0               1.3
# 54445.0               3.2
# 55794.0               4.0
# 56642.0               2.9
# 56957.0               4.0
# 57081.0               4.1
# 57189.0               3.7
# 60150.0               3.0
# 61111.0               4.5
# 63218.0               3.9
# 64445.0               3.2
# 66029.0               5.1
# 67938.0               4.9
# 81363.0               5.9
# 83088.0               5.3
# 91738.0               6.8
# 93940.0               6.0
# 98273.0               7.1
# 101302.0              7.9
# 105582.0              9.0
# 109431.0              8.7
# 112635.0              9.6
# 113812.0              8.2
# 116969.0              9.5
# 121872.0             10.5
# 122391.0             10.3

# %%
g = data.groupby('Salary')
g.mean()
# Out:
#           YearsExperience
# Salary
# 37731.0               1.5
# 39343.0               1.1
# 39891.0               2.2
# 43525.0               2.0
# 46205.0               1.3
# 54445.0               3.2
# 55794.0               4.0
# 56642.0               2.9
# 56957.0               4.0
# 57081.0               4.1
# 57189.0               3.7
# 60150.0               3.0
# 61111.0               4.5
# 63218.0               3.9
# 64445.0               3.2
# 66029.0               5.1
# 67938.0               4.9
# 81363.0               5.9
# 83088.0               5.3
# 91738.0               6.8
# 93940.0               6.0
# 98273.0               7.1
# 101302.0              7.9
# 105582.0              9.0
# 109431.0              8.7
# 112635.0              9.6
# 113812.0              8.2
# 116969.0              9.5
# 121872.0             10.5
# 122391.0             10.3

# %%
pip install sklearn

# %%
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
x,y = np.arange(10).reshape((5,2)),range(5)
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=1/3,random_state=1)

# %%
xtrain
# Out:
# array([[8, 9],
#        [0, 1],
#        [6, 7]])

# %%
ytrain
# Out:
# [4, 0, 3]

# %%
xtest
# Out:
# array([[4, 5],
#        [2, 3]])

# %%
ytest
# Out:
# [2, 1]

# %%
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
x,y = np.arange(10).reshape((5,2)),range(5)
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=1/3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
mymodel = model.fit(xtrain,ytrain)

# %%
y_pred = mymodel.predict(xtest)

# %%
y_pred
# Out:
# array([2., 1.])

# %%
ytest
# Out:
# [2, 1]

# %%
xtest
# Out:
# array([[4, 5],
#        [2, 3]])

# %%
mymodel.coef_
# Out:
# array([0.25, 0.25])

# %%
mymodel.intercept_
# Out:
# -0.2499999999999991

# %%
#y = mx + c , x = 6
9158.139*6 + 26137.24001419694
# Out:
# 81086.07401419693

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
mymodel = model.fit(xtrain,ytrain)

# %%
y_pred = mymodel.predict(xtest)

# %%
import matplotlib.pyplot as plt
y_pred = model.predict(xtest)
plt.plot(xtrain,ytrain)

# %%
import matplotlib.pyplot as plt
plt.scatter(xtrain,ytrain,color='red')
plt.plot(xtrain,mymodel.predict(xtrain))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-c339c7d1e3ff> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(xtrain,ytrain,color='red')
#       3 plt.plot(xtrain,mymodel.predict(xtrain))
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,8,11,14,17])
def gradient(x,y):
 a=0
 b=0
 a=np.array([1,2,3,4,5]) #y=3x+c
 b=np.array([5,8,11,14,17])
 plt.scatter(a,b,color='red')
 cost_old=0
 for i in range(1000):
    y_pred = a*x+b
    cost = (1/n)*sum([value**2 for value in (y - y_pred)])
    print(a,b,i,cost)
    plt.plot(x,y_pred)
    ad = -(2/n)*sum(x*(y-y_pred))
    yd = -(2/n)*sum(sum(y-y_pred))
    a = a-rate*ad
    b = b-rate*bd
    if math.isclose(cost,cot_old):
      break
    cost_old = cost
    return a,b

# %%
import pickle

# %%
with open('modelsave_pickle','wb') as file:
  pickle.dump(mymodel,file)

# %%
with open('modelsave_pickle','rb') as file:
  newmodel = pickle.load(file)

# %%
newmodel.predict([[2,4]])
# Out:
# array([1.5])

# %%
newmodel.predict([[5,6]])
# Out:
# array([2.5])

# %%
newmodel.predict([[1,2]])
# Out:
# array([0.5])

# %%
newmodel.predict([[6,4]])
# Out:
# array([2.25])

# %%
newmodel.coef_
# Out:
# array([0.25, 0.25])

# %%
newmodel.intercept_
# Out:
# -0.2499999999999991

# %%
#joblib starts

# %%
from sklearn.externals import joblib
joblib.dump(mymodel,'model_joblib')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['model_joblib']

# %%
mymodel = joblib.load('model_joblib')

# %%
#Linear Regression Model using Seaborn module

# %%
import seaborn as sns

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
data.ndim
# Out:
# 2

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
data.shape
# Out:
# (244, 7)

# %%
data.size
# Out:
# 1708

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
data.plot()

# %%
import seaborn as sns

# %%
dataset = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.set_style('whitegrid')
sns.lmplot(x='total_bill',y='tip',data=dataset)

# %%
import numpy as np
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
slices=[30,10,20,20,20]
activities=['car','bike','Load Truck','Goods Train','Cycle']
color=['c','m','r','k','b']
plt.pie(slices,labels=activities,colors=color,startangle=180)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
days = [12,23,45,56,67]
sleeping = [23,34,45,56,67]
eating = [22,34,46,57,68]
working = [29,40,50,60,70]
playing = [31,42,53,64,75]
plt.plot([],[],color = 'm',label = 'sleeping',linewidth = 5)
plt.plot([],[],color = 'c',label = 'eating',linewidth = 5)
plt.plot([],[],color = 'r',label = 'working',linewidth = 5)
plt.plot([],[],color = 'k',label = 'playing',linewidth  = 5)
plt.stackplot(days,sleeping,eating,working,playing,colors=['m','c','r','k'])
plt.title('Stack plot Dimensions')
plt.xlabel('Plot A')
plt.ylabel('Plot B')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4],[1,4,7,8],'ro-',label='line1')
plt.plot([1,2,3,4],[1,2,3,4],linewidth=5,label='line2')
plt.plot([5,6,7,8,9],[5,6,7,8,9],'ro-',label='line3')
plt.plot([5,6,7,8,9],[6,6,6,6,6],color='red',linestyle='-',marker='o',markersize=5,markerfacecolor='g')
plt.plot(0,10,0,20)
plt.title('Visualization')
plt.xlabel('Point a')
plt.ylabel('Point b')
plt.legend()
plt.show()
t = np.arange(2,6,0.3)
plt.plot(t,t,'ro-',t,t**4,'go')

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0,0.5,0.1)
t2 = np.arange(0.0,0.5,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.subplot(2,1,1)
plt.plot(x,y_sin)
plt.title('Sine Wave')
plt.subplot(2,1,2)
plt.title('Cosine Wave')
plt.plot(x,y_cos)
plt.show()
